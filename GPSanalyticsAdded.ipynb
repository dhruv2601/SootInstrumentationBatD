# %%
import pandas as pd
import os

# %%
CSVFILE_DIR = "/home/dhruv2601/IdeaProjects/Soot_Instrumenter/ThunderOutput.csv"

# %%
df = pd.read_csv(CSVFILE_DIR, sep='\t', encoding='utf-8-sig')
regex = '([a-zA-Z0-9_-])'
# df = df.rename(columns=dict((col, ''.join(re.findall(regex, col))) for col in df.columns))
df
# Out:
#     Serial       category                                    package  \
# 0        0   ANDROID_WEAR                       ch.publisheria.bring
# 1        2   ANDROID_WEAR                com.acmeaom.android.myradar
# 2        4   ANDROID_WEAR                       com.adi.remote.phone
# 3        5   ANDROID_WEAR                              com.aircanada
# 4        6   ANDROID_WEAR              com.amdroidalarmclock.amdroid
# 5        7   ANDROID_WEAR                   com.android2.calculator3
# 6        9   ANDROID_WEAR                            com.balysv.loop
# 7       10   ANDROID_WEAR                          com.baseapp.eyeem
# 8       11   ANDROID_WEAR                   com.bitdefender.security
# 9       13   ANDROID_WEAR     com.musicplayer.player.mp3player.white
# 10      15   ANDROID_WEAR                           com.nest.android
# 11      16   ANDROID_WEAR                   com.northpark.drinkwater
# 12      18   ANDROID_WEAR                         com.opl.transitnow
# 13      19   ANDROID_WEAR  com.overdrive.mobile.android.mediaconsole
# 14      20   ANDROID_WEAR             com.pelmorex.WeatherEyeAndroid
# 15      21   ANDROID_WEAR                    com.SearingMedia.Parrot
# 16      22   ANDROID_WEAR                         com.shazam.android
# 17      23   ANDROID_WEAR                    com.sillens.shapeupclub
# 18      24   ANDROID_WEAR                          com.spotify.music
# 19      25   ANDROID_WEAR                                 com.strava
# 20      26   ANDROID_WEAR                        com.stronglifts.app
# 21      27   ANDROID_WEAR                                com.stubhub
# 22      29   ANDROID_WEAR     com.google.android.apps.authenticator2
# 23      31   ANDROID_WEAR            com.google.android.apps.fitness
# 24      32   ANDROID_WEAR    com.google.android.apps.handwriting.ime
# 25      34   ANDROID_WEAR          com.google.android.apps.translate
# 26      35   ANDROID_WEAR       com.google.android.apps.walletnfcrel
# 27      36   ANDROID_WEAR              com.google.android.calculator
# 28      37   ANDROID_WEAR               com.google.android.deskclock
# 29      38   ANDROID_WEAR                      com.google.android.gm
# ..     ...            ...                                        ...
# 497    525  COMMUNICATION        org.adblockplus.adblockplussbrowser
# 498    526  COMMUNICATION                    org.adblockplus.browser
# 499    527  COMMUNICATION             org.mistergroup.muzutozvednout
# 500    528  COMMUNICATION                        org.mozilla.firefox
# 501    529         DATING                       air.com.flaxbin.chat
# 502    530  COMMUNICATION                   org.myklos.btautoconnect
# 503    531         DATING                             cdff.mobileapp
# 504    532         DATING                             chat.withgirls
# 505    533         DATING                      co.adultfnder.android
# 506    534  COMMUNICATION                park.outlook.sign.in.client
# 507    535         DATING                          co.dilmil.android
# 508    536         DATING                  co.zodiacmatch.freedating
# 509    537  COMMUNICATION                      xyz.klinker.messenger
# 510    538         DATING                com.appsgratis.loveinafrica
# 511    539         DATING                  com.asiandating.matchtrav
# 512    540         DATING                       com.atranssexualdate
# 513    541         DATING                  com.bewild.dating.android
# 514    522  COMMUNICATION          messengerchatapp.new17.update2017
# 515    523  COMMUNICATION                             mobi.drupe.app
# 516    524  COMMUNICATION               nl.alphaapps.checkforhotmail
# 517    525  COMMUNICATION        org.adblockplus.adblockplussbrowser
# 518    526  COMMUNICATION                    org.adblockplus.browser
# 519    527  COMMUNICATION             org.mistergroup.muzutozvednout
# 520    528  COMMUNICATION                        org.mozilla.firefox
# 521    529         DATING                       air.com.flaxbin.chat
# 522    530  COMMUNICATION                   org.myklos.btautoconnect
# 523    531         DATING                             cdff.mobileapp
# 524    532         DATING                             chat.withgirls
# 525    533         DATING                      co.adultfnder.android
# 526    534  COMMUNICATION                park.outlook.sign.in.client
#
#      target_sdk  min_sdk  totalFS  totalBS  totalSS  totalSF  totalSFS  \
# 0            27       16        0       18        8        0         3
# 1            26       15        1       14       14        1         2
# 2            25       16        1        9        6        1         0
# 3            24       19        1       12       14        1         3
# 4            27       14       23       26        5       23         1
# 5            25       14        1        1        2        1         0
# 6            27       16        0       23       19        0         3
# 7            26       15        2       12        6        2         4
# 8            25       15        2       25       26        2         0
# 9            25       16        5        0       11        5         0
# 10           27       19        2       32       25        2         4
# 11           24       16        0       29       16        0         0
# 12           25       14        1       13       15        1         3
# 13           27       14        3        6        4        3         2
# 14           25       21        4       24       12        4         2
# 15           27       19       12        0        8       12         2
# 16           27       21        5       10       11        5         2
# 17           27       19        0       18        4        0         0
# 18           19        9        2       10       39        2         0
# 19           25       19        1       19       17        1         3
# 20           26       21        1       10        6        1         0
# 21           27       21        0       16       10        0         3
# 22           23       10        0        2        0        0         0
# 23           26       16        2       31       10        2         2
# 24           25       15        1        3        7        1         0
# 25           24       17        2        8        8        2         1
# 26           25       21        0       46       10        0         0
# 27           26       21        0        0        3        0         0
# 28           26       19        2        5        4        2         1
# 29           28       16        3       65       23        3         2
# ..          ...      ...      ...      ...      ...      ...       ...
# 497          27       21        0        0        0        0         0
# 498          23       15        5       18       36        5         0
# 499          25       14        2        2        1        2         0
# 500          23       16        4       24       41        4         0
# 501          27       14        0        0        4        0         3
# 502          21       11        0        2        8        0         0
# 503          23       16        3        8       20        3         0
# 504          22        9        4        6       19        4         0
# 505          23       16        0        5       12        0         0
# 506          26       19        1       38       18        1         3
# 507          25       21        1       13       17        1         2
# 508          24       16        0        0        3        0         3
# 509          28       21       15       33       16       15        13
# 510          26       16        0       14        9        0         3
# 511          27       15        4        4        7        4         1
# 512          26       16        0        3        5        0         3
# 513          23       17        0        7       14        0         0
# 514          27       16        0       16        9        0         3
# 515          24       16        3       18       32        3         3
# 516          26       19        2       19       33        2         1
# 517          27       21        0        0        0        0         0
# 518          23       15        5       18       36        5         0
# 519          25       14        2        2        1        2         0
# 520          23       16        4       24       41        4         0
# 521          27       14        0        0        4        0         3
# 522          21       11        0        2        8        0         0
# 523          23       16        3        8       20        3         0
# 524          22        9        4        6       19        4         0
# 525          23       16        0        5       12        0         0
# 526          26       19        1       38       18        1         3
#
#      totalService  GPScalls  Unnamed: 12
# 0              18         0          NaN
# 1              15         0          NaN
# 2              10         0          NaN
# 3              13         0          NaN
# 4              49         1          NaN
# 5               2         0          NaN
# 6              23         0          NaN
# 7              14         0          NaN
# 8              27         1          NaN
# 9               5         0          NaN
# 10             34         1          NaN
# 11             29         0          NaN
# 12             14         0          NaN
# 13              9         1          NaN
# 14             28         1          NaN
# 15             12         0          NaN
# 16             15         0          NaN
# 17             18         0          NaN
# 18             12         0          NaN
# 19             20         1          NaN
# 20             11         0          NaN
# 21             16         0          NaN
# 22              2         0          NaN
# 23             33         0          NaN
# 24              4         0          NaN
# 25             10         0          NaN
# 26             46         0          NaN
# 27              0         0          NaN
# 28              7         0          NaN
# 29             68         0          NaN
# ..            ...       ...          ...
# 497             0         0          NaN
# 498            23         0          NaN
# 499             4         1          NaN
# 500            28         0          NaN
# 501             0         0          NaN
# 502             2         0          NaN
# 503            11         0          NaN
# 504            10         0          NaN
# 505             5         0          NaN
# 506            39         0          NaN
# 507            14         1          NaN
# 508             0         0          NaN
# 509            48         1          NaN
# 510            14         0          NaN
# 511             8         0          NaN
# 512             3         0          NaN
# 513             7         0          NaN
# 514            16         0          NaN
# 515            21         0          NaN
# 516            21         0          NaN
# 517             0         0          NaN
# 518            23         0          NaN
# 519             4         1          NaN
# 520            28         0          NaN
# 521             0         0          NaN
# 522             2         0          NaN
# 523            11         0          NaN
# 524            10         0          NaN
# 525             5         0          NaN
# 526            39         0          NaN
#
# [527 rows x 13 columns]

# %%
count = 0
for i, rows in df.iterrows():
    if(rows['GPScalls']==1):
        count+=1
print(count)
print(df.shape[0])
# Out:
# 36
# 527
