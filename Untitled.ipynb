# %%
import pandas as pd

# %%
df = pd.read_csv("2Cats.csv", sep='\t')
df
# Out:
#       Unnamed: 0      category                                   package   \
# 0              0  ANDROID_WEAR                       ch.publisheria.bring
# 1              1  ANDROID_WEAR                             com.aa.android
# 2              2  ANDROID_WEAR                com.acmeaom.android.myradar
# 3              3  ANDROID_WEAR                       com.adhoclabs.burner
# 4              4  ANDROID_WEAR                       com.adi.remote.phone
# 5              5  ANDROID_WEAR                              com.aircanada
# 6              6  ANDROID_WEAR              com.amdroidalarmclock.amdroid
# 7              7  ANDROID_WEAR                   com.android2.calculator3
# 8              8  ANDROID_WEAR               com.appgeneration.itunerfree
# 9              9  ANDROID_WEAR                            com.balysv.loop
# 10            10  ANDROID_WEAR                          com.baseapp.eyeem
# 11            11  ANDROID_WEAR                   com.bitdefender.security
# ...
